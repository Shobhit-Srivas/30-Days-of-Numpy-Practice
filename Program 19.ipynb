# %% [markdown]
# # Write a program to calculate the sum of digits of a number.

# %%
n = int(input("Enter a number: "))
total = 0
while n != 0:
    total += n % 10
    n //= 10
print(f"The sum of digits of a number is {total}")
# Out:
# Enter a number:  123
# The sum of digits of a number is 6
