# %% [markdown]
# # Write a program to count the number of words starting with a vowel in a string.

# %%
string = input("Enter a sentence: ")
words = string.split()
count = 0
vowels = "aeiouAEIOU"
for word in words:
    if word[0] in vowels:
        count += 1
print("Number of words starting with a vowel:", count)
# Out:
# Enter a sentence:  sting is arre
# Number of words starting with a vowel: 2
