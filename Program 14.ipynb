# %% [markdown]
# # Create a 2×4 array filled with the number 7.

# %%
import numpy as np
arr = np.full((2, 4), 7)
print(f"2*4 Matrix Array filled with number 7\n: {arr}")
# Out:
# 2*4 Matrix Array filled with number 7
# : [[7 7 7 7]
#  [7 7 7 7]]
