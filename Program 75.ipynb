# %% [markdown]
# # Create a program to find the longest word in a sentence.

# %%
class LongestWord:
    def __init__(self, sentence):
        self.sentence = sentence
    def find_longest_word(self):
        words = self.sentence.split()
        longest = words[0]
        for word in words:
            if len(word) > len(longest):
                longest = word
        return longest
        
sentence = input("Enter a sentence: ")
obj = LongestWord(sentence)
print("Longest word is:", obj.find_longest_word())
# Out:
# Enter a sentence:  This is a pen
# Longest word is: This
