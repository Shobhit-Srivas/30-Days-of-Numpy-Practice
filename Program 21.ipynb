# %% [markdown]
# # Flatten a 2D array.

# %%
import numpy as np
arr = np.arange(1, 10).reshape(3, 3)
one_d = arr.flatten()
print(f"Original Matrix is\n: {arr}")
print(f"Flatten Matrix is\n: {one_d}")
# Out:
# Original Matrix is
# : [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# Flatten Matrix is
# : [1 2 3 4 5 6 7 8 9]
