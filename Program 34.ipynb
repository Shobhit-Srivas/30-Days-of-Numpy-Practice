# %% [markdown]
# # Create a program that removes duplicates from a list.

# %%
def Remove(arr):
    print(list(set(arr)))
    
numbers = list(map(int, input("Enter numbers seperated by space: ").split()))
Remove(numbers)
# Out:
# Enter numbers seperated by space:  1 2 3 1 3 4 5
# [1, 2, 3, 4, 5]
