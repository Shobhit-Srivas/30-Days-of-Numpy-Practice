# %% [markdown]
# # Find sum, mean, and standard deviation of the array.

# %%
import numpy as np
arr = np.array([1, 4, 5, 9, 8, 2, 7])
print(f"Sum of array: {arr.sum()}")
print(f"Mean of array: {arr.mean()}")
print(f"Standard Deviation of array: {arr.std()}")
# Out:
# Sum of array: 36
# Mean of array: 5.142857142857143
# Standard Deviation of array: 2.799416848895061
