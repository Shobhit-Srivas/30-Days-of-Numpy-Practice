# %% [markdown]
# # Create a 3×3 random integer array.

# %%
import numpy as np
arr = np.random.randint(1, 101, size = (3, 3))
print(f"Output is: {arr}")
# Out:
# Output is: [[77  9  2]
#  [97 95 92]
#  [38 25 42]]
