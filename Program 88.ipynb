# %% [markdown]
# # Create a program that counts words, characters, and lines in a paragraph.

# %%
string = input("Enter a string: ")
char = len(string)
word = string.split()
words = len(word)
line = string.split("\n")
lines = len(line)
print(f"Total characters are {char}, total words are {words} and total lines are {lines}")
# Out:
# Enter a string:  string is a good things and this sa
# Total characters are 35, total words are 8 and total lines are 1
