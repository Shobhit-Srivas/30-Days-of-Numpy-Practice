# %% [markdown]
# # Write a program to parse a date string and display it in a different format.

# %%
from datetime import datetime
date_string = input("Enter date (DD-MM-YYYY): ")
date_object = datetime.strptime(date_string, "%d-%m-%Y")
new_format = date_object.strftime("%B %d, %Y")
print("Formatted Date:", new_format)
# Out:
# Enter date (DD-MM-YYYY):  19-05-2026
# Formatted Date: May 19, 2026
