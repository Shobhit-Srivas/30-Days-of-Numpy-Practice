# %% [markdown]
# # Write a program to merge two dictionaries.

# %%
dict1 = {"name": "Rohan", "age": "23"}
dict2 = {"phone": "1593578426", "address": "Prayagraj"}
merged = dict1 | dict2
print(merged)
# Out:
# {'name': 'Rohan', 'age': '23', 'phone': '1593578426', 'address': 'Prayagraj'}
