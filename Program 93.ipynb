# %% [markdown]
# # Create a script that takes a sentence and removes all stop words.

# %%
sentence = input("Enter a sentence: ")
stop_words = ["is", "am", "are", "the", "a", "an", "in", "on", "at", "and", "or", "to"]
words = sentence.split()
filtered_words = []
for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)
result = " ".join(filtered_words)
print("Sentence after removing stop words:")
print(result)
# Out:
# Enter a sentence:  this is a man
# Sentence after removing stop words:
# this man
