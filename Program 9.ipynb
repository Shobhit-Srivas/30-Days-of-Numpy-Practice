# %% [markdown]
# # Write a Python script to reverse a given string.

# %%
string = input("Enter a string: ")
print(f"In reverse order of string is {string[::-1]}")
# Out:
# Enter a string:  Mohit
# In reverse order of string is tihoM
