# %% [markdown]
# # Create a 3×3 identity matrix.

# %%
import numpy as np
identity_matrix = np.identity(3) # here We use both function "identity() and eye()" for find the identity matrix but mostly used eye() function because it is more flexible.
identity_matrix = np.eye(3)
print(f"Identity Matrix is\n: {identity_matrix}")
# Out:
# Identity Matrix is
# : [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
