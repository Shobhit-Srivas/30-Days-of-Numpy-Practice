# %% [markdown]
# # Write a Python program to swap two variables.

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print(f"Before Swap Values a = {a} and b = {b}")
t = a
a = b
b = t
print(f"After Swap Values a= {a} and b = {b}")
