# %% [markdown]
# # Create a 3×3 matrix and print the second row.

# %%
import numpy as np
arr = np.random.randint(1, 10, size = (3, 3))
print(f"Original Array is\n: {arr}")
print(f"Second Row of Array\n: {arr[1]}")
# Out:
# Original Array is
# : [[1 3 7]
#  [2 1 6]
#  [8 1 1]]
# Second Row of Array
# : [2 1 6]
