# %% [markdown]
# # Create an array using linspace() from 0 to 1 with 5 values.

# %%
import numpy as np
arr = np.linspace(0, 1, 5)
print(f"Array using linspace is: {arr}")
# Out:
# Array using linspace is: [0.   0.25 0.5  0.75 1.  ]
