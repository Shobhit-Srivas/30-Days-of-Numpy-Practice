# %% [markdown]
# # Write a Python program to merge two dictionaries into one.

# %%
dict1 = {"name": "Shobhit", "age": 24}
dict2 = {"course": "MCA", "PhoneNo": "1478523698"}
print(dict1 | dict2)
# Out:
# {'name': 'Shobhit', 'age': 24, 'course': 'MCA', 'PhoneNo': '1478523698'}
