# %% [markdown]
# # Write a script that finds the longest sentence in a paragraph.

# %%
import re
paragraph = """
Python is easy to learn.
Data science is very popular nowadays.
Machine learning helps in making predictions and solving complex problems.
"""
sentences = re.split(r'[.!?]', paragraph)
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
longest_sentence = max(sentences, key=len)
print("Longest Sentence:")
print(longest_sentence)
# Out:
# Longest Sentence:
# Machine learning helps in making predictions and solving complex problems
