# %% [markdown]
# # Write a Python program to find and replace text in a string.

# %%
string = input("Enter a string: ")
find = input("Enter a string to find: ")
replace = input("Enter a string to replace: ")
if find in string:
    print(string.replace(find,replace))
else:
    print("Find string not found")
# Out:
# Enter a string:  this is a pen
# Enter a string to find:  no
# Enter a string to replace:  non
# Find string not found
