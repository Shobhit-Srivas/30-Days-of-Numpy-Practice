# %% [markdown]
# # Take user input and display it back to the user.

# %%
user = input("Enter any input: ")
print(f"User Enetered Input is: {user}")
# Out:
# Enter any input:  this is
# User Enetered Input is this is
