# %% [markdown]
# # Write a function that returns a new string made of every third character of the original string.

# %%
def every_third_character(text):
    return text[::3]

string = input("Enter a string: ")
result = every_third_character(string)
print("Original String :", string)
print("New String      :", result)
# Out:
# Enter a string:  programming python
# Original String : programming python
# New String      : pgmnph
